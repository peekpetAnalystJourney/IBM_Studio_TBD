# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Peter Joseph**
#
# Analyst*

# %% [markdown]
# *I am interested in data science because it can help firm makes an informed-data-driven-decision*

# %% [markdown]
# ### The code in the next cell will create a simple plot

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3],[1,2,3]);
plt.show()

# %% [markdown]
# - one
#
# - two
#
# - three
#
# [IBM Watson Cloud](https://dataplatform.cloud.ibm.com/canvas/flows/99ca3eaf-bae4-4635-924d-5d55889cfff5?context=cpdaas&projectGuid=82fc8fc3-6ac8-4bca-8af6-4a2cb4540401&env_id=mods-82fc8fc3-6ac8-4bca-8af6-4a2cb4540401)
#
# | sample | sample |
# | ------ | ------ |
# | cell1  | cell2  |
